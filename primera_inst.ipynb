# %%
import pandas as pd
import numpy as np

df = pd.read("transacciones_banco.csv")

df.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2 import numpy as np
#       3
# ----> 4 df = pd.read("transacciones_banco.csv")
#       5
#       6 df.shape
#
# AttributeError: module 'pandas' has no attribute 'read'
